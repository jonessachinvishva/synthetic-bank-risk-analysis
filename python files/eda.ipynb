# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## Create a Synthetic Bank
#
# This notebook performs exploratory data analysis on the historical macroeconomic and retail banking dataset collected from the Bank of England (BoE) and the Office for National Statistics (ONS).

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Plot settings
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 11

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("Final_DS.csv")

# Convert Date column
df["Date"] = pd.to_datetime(df["Date"])

# Display first rows
df.head()
# Out:
#         Date  Year     Month  Bank_Rate   CPI  Unemployment_Rate  \
# 0 2008-01-01  2008   January      5.500 2.200              5.200
# 1 2008-02-01  2008  February      5.250 2.500              5.200
# 2 2008-03-01  2008     March      5.250 2.500              5.300
# 3 2008-04-01  2008     April      5.000 3.000              5.200
# 4 2008-05-01  2008       May      5.000 3.300              5.400
#
#    House_Price_Index  GDP_Growth  Current_Accounts  Savings_Accounts  \
# 0             65.600       0.400             33417            224159
# 1             65.000       0.400             31492            226772
# 2             64.500       0.400             32823            227769
# 3             64.700      -0.500             31895            233766
# 4             65.100      -0.500             32210            237820
#
#    Mortgage_Approvals  Consumer_Credit  Credit_Card_Lending
# 0               71326           101598                54232
# ...

# %% [markdown]
# **Dataset Shape**

# %%
print("Dataset Shape")
print("-"*40)

print(f"Number of observations: {df.shape[0]}")
print(f"Number of variables: {df.shape[1]}")
# Out:
# Dataset Shape
# ----------------------------------------
# Number of observations: 216
# Number of variables: 13

# %% [markdown]
# **Data Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 216 non-null    datetime64[ns]
#  1   Year                 216 non-null    int64
#  2   Month                216 non-null    object
#  3   Bank_Rate            216 non-null    float64
#  4   CPI                  216 non-null    float64
#  5   Unemployment_Rate    216 non-null    float64
#  6   House_Price_Index    216 non-null    float64
#  7   GDP_Growth           216 non-null    float64
#  8   Current_Accounts     216 non-null    int64
#  9   Savings_Accounts     216 non-null    int64
#  10  Mortgage_Approvals   216 non-null    int64
#  11  Consumer_Credit      216 non-null    int64
#  12  Credit_Card_Lending  216 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(1)
# memory usage: 22.1+ KB

# %% [markdown]
# **Check Data Types**

# %%
df.dtypes
# Out:
# Date                   datetime64[ns]
# Year                            int64
# Month                          object
# Bank_Rate                     float64
# CPI                           float64
# Unemployment_Rate             float64
# House_Price_Index             float64
# GDP_Growth                    float64
# Current_Accounts                int64
# Savings_Accounts                int64
# Mortgage_Approvals              int64
# Consumer_Credit                 int64
# Credit_Card_Lending             int64
# dtype: object

# %% [markdown]
# Column Names

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Bank_Rate', 'CPI', 'Unemployment_Rate',
#        'House_Price_Index', 'GDP_Growth', 'Current_Accounts',
#        'Savings_Accounts', 'Mortgage_Approvals', 'Consumer_Credit',
#        'Credit_Card_Lending'],
#       dtype='object')

# %% [markdown]
# **Missing Values**

# %%
missing = df.isnull().sum()
missing
# Out:
# Date                   0
# Year                   0
# Month                  0
# Bank_Rate              0
# CPI                    0
# Unemployment_Rate      0
# House_Price_Index      0
# GDP_Growth             0
# Current_Accounts       0
# Savings_Accounts       0
# Mortgage_Approvals     0
# Consumer_Credit        0
# Credit_Card_Lending    0
# dtype: int64

# %% [markdown]
# **Check Duplicate Rows**

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate rows: {duplicates}")
# Out:
# Duplicate rows: 0

# %% [markdown]
# **Descriptive Statistics**

# %%
df.describe().T
# Out:
#                       count                 mean                  min  \
# Date                    216  2016-12-15 17:33:20  2008-01-01 00:00:00
# Year                216.000             2016.500             2008.000
# Bank_Rate           216.000                1.456                0.100
# CPI                 216.000                2.994               -0.100
# Unemployment_Rate   216.000                5.540                3.600
# House_Price_Index   216.000               76.939               54.500
# GDP_Growth          216.000                0.328              -19.900
# Current_Accounts    216.000           174749.292            31492.000
# Savings_Accounts    216.000           220125.755           148703.000
# Mortgage_Approvals  216.000            60216.120             9369.000
# Consumer_Credit     216.000            73758.083            60802.000
# Credit_Card_Lending 216.000            50775.472            41129.000
#
# ...

# %% [markdown]
# **BOX PLOT**

# %% [markdown]
# **Bank Rate**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Bank_Rate"])
plt.title("Boxplot of Bank Rate")
plt.xlabel("Bank Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **CPI**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["CPI"])
plt.title("Boxplot of CPI")
plt.xlabel("CPI Inflation (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **GDP Growth**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["GDP_Growth"])
plt.title("Boxplot of GDP Growth")
plt.xlabel("GDP Growth (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Unemployment Rate**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Unemployment_Rate"])
plt.title("Boxplot of Unemployment Rate")
plt.xlabel("Unemployment Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **House Price Index**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["House_Price_Index"])
plt.title("Boxplot of House Price Index")
plt.xlabel("House Price Index")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Current Accounts**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Current_Accounts"])
plt.title("Boxplot of Current Accounts")
plt.xlabel("Current Accounts")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Savings Accounts**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Savings_Accounts"])
plt.title("Boxplot of Savings Accounts")
plt.xlabel("Savings Accounts")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Mortgage Approvals**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Mortgage_Approvals"])
plt.title("Boxplot of Mortgage Approvals")
plt.xlabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Consumer Credit**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Consumer_Credit"])
plt.title("Boxplot of Consumer Credit")
plt.xlabel("Consumer Credit")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Credit Card Lending**

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=df["Credit_Card_Lending"])
plt.title("Boxplot of Credit Card Lending")
plt.xlabel("Credit Card Lending")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Histograms For Numerical Variables**

# %% [markdown]
# **Bank Rate**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df["Bank_Rate"], bins=20, kde=True)
plt.title("Distribution of Bank Rate")
plt.xlabel("Bank Rate (%)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **CPI**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["CPI"], bins=20, kde=True)
plt.title("Distribution of CPI")
plt.xlabel("CPI Inflation (%)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **GDP Growth**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["GDP_Growth"], bins=20, kde=True)
plt.title("Distribution of GDP Growth")
plt.xlabel("GDP Growth (%)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **House Price Index**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["House_Price_Index"], bins=20, kde=True)
plt.title("Distribution of House Price Index")
plt.xlabel("House Price Index")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Current Accounts**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Current_Accounts"], bins=20, kde=True)
plt.title("Distribution of Current Accounts")
plt.xlabel("Current Accounts")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Savings Accounts**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Savings_Accounts"], bins=20, kde=True)
plt.title("Distribution of Savings Accounts")
plt.xlabel("Savings Accounts")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Mortgage_Approvals"], bins=20, kde=True)
plt.title("Distribution of Mortgage Approvals")
plt.xlabel("Mortgage Approvals")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Consumer Credit**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Consumer_Credit"], bins=20, kde=True)
plt.title("Distribution of Consumer Credit")
plt.xlabel("Consumer Credit")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Credit Card Lending**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Credit_Card_Lending"], bins=20, kde=True)
plt.title("Distribution of Credit Card Lending")
plt.xlabel("Credit Card Lending")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
numeric_columns = [
    "Bank_Rate",
    "CPI",
    "GDP_Growth",
    "Unemployment_Rate",
    "House_Price_Index",
    "Current_Accounts",
    "Savings_Accounts",
    "Mortgage_Approvals",
    "Consumer_Credit",
    "Credit_Card_Lending"
]

correlation_matrix = df[numeric_columns].corr()

correlation_matrix
# Out:
#                      Bank_Rate    CPI  GDP_Growth  Unemployment_Rate  \
# Bank_Rate                1.000  0.371      -0.067             -0.310
# CPI                      0.371  1.000      -0.018             -0.134
# GDP_Growth              -0.067 -0.018       1.000              0.026
# Unemployment_Rate       -0.310 -0.134       0.026              1.000
# House_Price_Index        0.504  0.359       0.054             -0.821
# Current_Accounts         0.414  0.347       0.076             -0.704
# Savings_Accounts         0.378  0.084      -0.070              0.712
# Mortgage_Approvals      -0.238 -0.335       0.499             -0.366
# Consumer_Credit          0.316 -0.026      -0.143             -0.038
# Credit_Card_Lending      0.173 -0.186      -0.117              0.064
#
#                      House_Price_Index  Current_Accounts  Savings_Accounts  \
# Bank_Rate                        0.504             0.414             0.378
# ...

# %% [markdown]
# **Correlation Matrix**

# %%
correlation_matrix = df[numeric_columns].corr()

correlation_matrix
# Out:
#                      Bank_Rate    CPI  GDP_Growth  Unemployment_Rate  \
# Bank_Rate                1.000  0.371      -0.067             -0.310
# CPI                      0.371  1.000      -0.018             -0.134
# GDP_Growth              -0.067 -0.018       1.000              0.026
# Unemployment_Rate       -0.310 -0.134       0.026              1.000
# House_Price_Index        0.504  0.359       0.054             -0.821
# Current_Accounts         0.414  0.347       0.076             -0.704
# Savings_Accounts         0.378  0.084      -0.070              0.712
# Mortgage_Approvals      -0.238 -0.335       0.499             -0.366
# Consumer_Credit          0.316 -0.026      -0.143             -0.038
# Credit_Card_Lending      0.173 -0.186      -0.117              0.064
#
#                      House_Price_Index  Current_Accounts  Savings_Accounts  \
# Bank_Rate                        0.504             0.414             0.378
# ...

# %% [markdown]
# **Correlation ranking**

# %%
corr_target = df.corr(numeric_only=True)["Mortgage_Approvals"].sort_values(ascending=False)
print(corr_target)
# Out:
# Mortgage_Approvals     1.000
# GDP_Growth             0.499
# Year                   0.402
# Current_Accounts       0.343
# House_Price_Index      0.337
# Bank_Rate             -0.238
# Credit_Card_Lending   -0.303
# Consumer_Credit       -0.328
# CPI                   -0.335
# Unemployment_Rate     -0.366
# Savings_Accounts      -0.539
# Name: Mortgage_Approvals, dtype: float64

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f",
            linewidths=0.5)

plt.title("Correlation Matrix of Macroeconomic and Retail Banking Variables")
plt.show()

# %% [markdown]
# **Bank Rate vs Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="Bank_Rate",
    y="Mortgage_Approvals",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("Bank Rate vs Mortgage Approvals")
plt.xlabel("Bank Rate (%)")
plt.ylabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# **CPI vs Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="CPI",
    y="Mortgage_Approvals",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("CPI vs Mortgage Approvals")
plt.xlabel("CPI Inflation (%)")
plt.ylabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# **GDP Growth vs Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="GDP_Growth",
    y="Mortgage_Approvals",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("GDP Growth vs Mortgage Approvals")
plt.xlabel("GDP Growth (%)")
plt.ylabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Unemployment Rate vs Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="Unemployment_Rate",
    y="Mortgage_Approvals",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("Unemployment Rate vs Mortgage Approvals")
plt.xlabel("Unemployment Rate (%)")
plt.ylabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# **House Price Index vs Mortgage Approvals**

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="House_Price_Index",
    y="Mortgage_Approvals",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("House Price Index vs Mortgage Approvals")
plt.xlabel("House Price Index")
plt.ylabel("Mortgage Approvals")
plt.tight_layout()
plt.show()

# %% [markdown]
# Bank Rate vs Savings Accounts

# %%
plt.figure(figsize=(8,5))
sns.regplot(
    x="Bank_Rate",
    y="Savings_Accounts",
    data=df,
    scatter_kws={"alpha":0.6},
    line_kws={"color":"red"}
)
plt.title("Bank Rate vs Savings Accounts")
plt.xlabel("Bank Rate (%)")
plt.ylabel("Savings Accounts")
plt.tight_layout()
plt.show()

# %% [markdown]
# Pairplot

# %%
selected = [
    "Bank_Rate",
    "CPI",
    "GDP_Growth",
    "Unemployment_Rate",
    "Mortgage_Approvals"
]

sns.pairplot(df[selected])
plt.show()
